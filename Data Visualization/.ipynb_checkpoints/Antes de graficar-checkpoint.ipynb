# %% [markdown]
# # PROYECTO: INDICADORES DE SALUD - GRAFICAS

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cargar bases de datos

# %%
#Cargar base de datos egresos
file = '../../Registros/Bases de datos/2010_2022/Cambio claves/egresos.csv'
egresos = pd.read_csv(file, on_bad_lines='skip')
egresos.head()
# Out:
#    ID                               CLUES       INGRE      EGRESO  DIAS_ESTA  \
# 0   1  CENTENARIO HOSPITAL MIGUEL HIDALGO  2010-01-04  2010-01-04          1
# 1   3  CENTENARIO HOSPITAL MIGUEL HIDALGO  2010-01-06  2010-01-06          1
# 2   4  CENTENARIO HOSPITAL MIGUEL HIDALGO  2010-01-05  2010-01-05          1
# 3   5  CENTENARIO HOSPITAL MIGUEL HIDALGO  2010-01-04  2010-01-04          1
# 4   8  CENTENARIO HOSPITAL MIGUEL HIDALGO  2010-01-04  2010-01-04          1
#
#   CVEEDAD  EDAD NACIOEN SEXO   PESO  ...           MUNIC LOC TIPSERV  \
# 0   MESES     2      NO    M  999.0  ...  AGUASCALIENTES   1  NORMAL
# 1    AÑOS     6     NaN    H  999.0  ...        ASIENTOS   3  NORMAL
# 2    AÑOS     5     NaN    H  999.0  ...        EL LLANO   3  NORMAL
# 3    AÑOS    18     NaN    H  999.0  ...  AGUASCALIENTES   1  NORMAL
# 4    AÑOS    17     NaN    M  999.0  ...     JESUS MARIA   1  NORMAL
#
#              PROCED                                           DIAG_INI  \
# 0  CONSULTA EXTERNA  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...
# 1  CONSULTA EXTERNA                                  LEUCEMIA LINFOIDE
# 2  CONSULTA EXTERNA                                  LEUCEMIA LINFOIDE
# 3  CONSULTA EXTERNA                           ENFERMEDAD RENAL CRÓNICA
# 4  CONSULTA EXTERNA                           ENFERMEDAD RENAL CRÓNICA
#
#                                             AFECPRIN          VEZ CAUSAEXT  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...  SUBSECUENTE      NaN
# 1                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 2                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 3                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
# 4                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
#
#   INFEC  MOTEGRE
# 0    NO  MEJORIA
# 1    NO  MEJORIA
# 2    NO  MEJORIA
# 3    NO  MEJORIA
# 4    NO  MEJORIA
#
# [5 rows x 22 columns]

# %%
# Asignar tipo de dato en formato fecha para ingreso y egreso hospitalario
egresos['EGRESO'] = pd.to_datetime(egresos['EGRESO'])
egresos['INGRE'] = pd.to_datetime(egresos['INGRE'])

# %%
#Cargar base de datos afecciones
file = '../../Registros/Bases de datos/2010_2022/Cambio claves/afecciones.csv'
afecciones = pd.read_csv(file, on_bad_lines='skip')
afecciones.head()
# Out:
#       ID  NUMAFEC                                        AFEC
# 0    399        2  FRACTURA DE HUESOS DEL CRÁNEO Y DE LA CARA
# 1    399        3                      FRACTURA DEL ANTEBRAZO
# 2    399        1            HIPERTENSIÓN ESENCIAL (PRIMARIA)
# 3  25245        1             ATENCIÓN PARA LA ANTICONCEPCIÓN
# 4  25569        1             ATENCIÓN PARA LA ANTICONCEPCIÓN

# %%
#Cargar base de datos procedimientos
file = '../../Registros/Bases de datos/2010_2022/Cambio claves/procedimientos.csv'
procedimientos = pd.read_csv(file, on_bad_lines='skip')
procedimientos.head()
# Out:
#       ID  NUMPROMED        TIPO       PROMED     ANEST QUIROF    QH    QM
# 0  10952          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN  99.0  99.0
# 1  23436          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN   1.0   0.0
# 2  23659          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN   1.0   0.0
# 3  23789          1  QUIRURGICO  LAPAROTOMÍA   GENERAL     EN  99.0  99.0
# 4  24367          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN   1.0   0.0

# %% [markdown]
# ## Agregar columnas

# %% [markdown]
# ### Número de procedimientos por paciente
#
# Para no crear una nueva columna por cada procedimiento que tenga un paciente (77 máximo), tomamos el número total de procedimientos por cada ID.

# %%
# Obtener el valor máximo de número de procedimiento para cada ID
conteo = procedimientos.groupby(['ID'])['NUMPROMED'].max().sort_values(ascending = False).to_frame().reset_index()
conteo.NUMPROMED.value_counts()
# Out:
# 1     179303
# 2      69416
# 3      30987
# 4      12477
# 5       5189
# 6       2342
# 7       1087
# 8        877
# 9        104
# 11        45
# 10        43
# 12        19
# 13        17
# 16        14
# 15         8
# 21         6
# 18         6
# 14         5
# 17         4
# 29         4
# 24         3
# 25         3
# 26         3
# 19         2
# 20         2
# 22         2
# 33         2
# 46         1
# 23         1
# 27         1
# 31         1
# 36         1
# 39         1
# 77         1
# Name: NUMPROMED, dtype: int64

# %%
#Combinar egresos con el conteo de número de procedimientos
egresos = egresos.merge(conteo, how = 'left', on = 'ID')
#Los IDS sin procedimientos rellenarlos con un 0
egresos['NUMPROMED'] = egresos['NUMPROMED'].fillna(0)
egresos.head()
# Out:
#    ID                               CLUES      INGRE     EGRESO  DIAS_ESTA  \
# 0   1  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 1   3  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 2   4  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 3   5  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 4   8  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
#
#   CVEEDAD  EDAD NACIOEN SEXO   PESO  ...  LOC TIPSERV            PROCED  \
# 0   MESES     2      NO    M  999.0  ...    1  NORMAL  CONSULTA EXTERNA
# 1    AÑOS     6     NaN    H  999.0  ...    3  NORMAL  CONSULTA EXTERNA
# 2    AÑOS     5     NaN    H  999.0  ...    3  NORMAL  CONSULTA EXTERNA
# 3    AÑOS    18     NaN    H  999.0  ...    1  NORMAL  CONSULTA EXTERNA
# 4    AÑOS    17     NaN    M  999.0  ...    1  NORMAL  CONSULTA EXTERNA
#
#                                             DIAG_INI  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...
# 1                                  LEUCEMIA LINFOIDE
# 2                                  LEUCEMIA LINFOIDE
# 3                           ENFERMEDAD RENAL CRÓNICA
# 4                           ENFERMEDAD RENAL CRÓNICA
#
#                                             AFECPRIN          VEZ CAUSAEXT  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...  SUBSECUENTE      NaN
# 1                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 2                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 3                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
# 4                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
#
#   INFEC  MOTEGRE NUMPROMED
# 0    NO  MEJORIA       1.0
# 1    NO  MEJORIA       1.0
# 2    NO  MEJORIA       1.0
# 3    NO  MEJORIA       1.0
# 4    NO  MEJORIA       1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Número de afecciones por paciente
#
# Para no crear una nueva columna por cada comorbilidad que tenga un paciente (10 máximo), tomamos el número total de comorbilidades por cada ID.

# %%
#Obtener el conteo de número de afecciones por paciente
conteo = afecciones.groupby(['ID'])['NUMAFEC'].max().sort_values(ascending = False).to_frame().reset_index()
conteo.NUMAFEC.value_counts()
# Out:
# 1     155107
# 2      32138
# 3      16219
# 4       8367
# 5       3997
# 6       1935
# 7        636
# 8         55
# 9          8
# 10         3
# Name: NUMAFEC, dtype: int64

# %%
#Agregar a la tabla egresos una columna con el número de afecciones por paciente
egresos = egresos.merge(conteo, how = 'left', on = 'ID')
egresos.head()
# Out:
#    ID                               CLUES      INGRE     EGRESO  DIAS_ESTA  \
# 0   1  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 1   3  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 2   4  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 3   5  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 4   8  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
#
#   CVEEDAD  EDAD NACIOEN SEXO   PESO  ...  TIPSERV            PROCED  \
# 0   MESES     2      NO    M  999.0  ...   NORMAL  CONSULTA EXTERNA
# 1    AÑOS     6     NaN    H  999.0  ...   NORMAL  CONSULTA EXTERNA
# 2    AÑOS     5     NaN    H  999.0  ...   NORMAL  CONSULTA EXTERNA
# 3    AÑOS    18     NaN    H  999.0  ...   NORMAL  CONSULTA EXTERNA
# 4    AÑOS    17     NaN    M  999.0  ...   NORMAL  CONSULTA EXTERNA
#
#                                             DIAG_INI  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...
# 1                                  LEUCEMIA LINFOIDE
# 2                                  LEUCEMIA LINFOIDE
# 3                           ENFERMEDAD RENAL CRÓNICA
# 4                           ENFERMEDAD RENAL CRÓNICA
#
#                                             AFECPRIN          VEZ CAUSAEXT  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...  SUBSECUENTE      NaN
# 1                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 2                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 3                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
# 4                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
#
#   INFEC  MOTEGRE NUMPROMED NUMAFEC
# 0    NO  MEJORIA       1.0     NaN
# 1    NO  MEJORIA       1.0     NaN
# 2    NO  MEJORIA       1.0     NaN
# 3    NO  MEJORIA       1.0     NaN
# 4    NO  MEJORIA       1.0     NaN
#
# [5 rows x 24 columns]

# %%
#Todos los IDS sin afección llenarlos con un cero
egresos['NUMAFEC'] = egresos['NUMAFEC'].fillna(0)
egresos['NUMAFEC'].value_counts()
# Out:
# 1.0     155025
# 0.0     102568
# 2.0      32105
# 3.0      16202
# 4.0       8363
# 5.0       3997
# 6.0       1935
# 7.0        636
# 8.0         55
# 9.0          8
# 10.0         3
# Name: NUMAFEC, dtype: int64

# %% [markdown]
# ## Corrección de número de afecciones
#
# Con el código anterior se cuenta el número de comorbilidades de la tabla afecciones, el problema es que hay comorbilidades que son la misma que la afección principal, lo cual por definición no es posible.
# En el siguiente código solo contaremos el número de comorbilidades del paciente que no están especificados como afección principal.

# %%
# Crear el diccionario vacío
diccionario = {}

# Iterar sobre cada fila del dataframe
for index, row in afecciones.iterrows():
    paciente_id = row['ID']
    comorbilidad = row['AFEC']

    # Verificar si el ID del paciente ya existe en el diccionario
    if paciente_id in diccionario:
        # Agregar la comorbilidad a la lista existente
        diccionario[paciente_id].append(comorbilidad)
    else:
        # Crear una nueva lista de comorbilidades para el ID del paciente
        diccionario[paciente_id] = [comorbilidad]

# %%
# Variable de contador
contador = 0

# Recorrer cada fila del dataframe 'egresos'
for index, row in egresos.iterrows():
    paciente_id = row['ID']
    afec_principal = row['AFECPRIN']

    # Verificar si el paciente tiene una comorbilidad principal en el diccionario
    if paciente_id in diccionario and afec_principal in diccionario[paciente_id]:
        # Eliminar la comorbilidad principal del diccionario
        diccionario[paciente_id].remove(afec_principal)
        # Incrementar el contador
        contador += 1

# %%
#Este es el número de registros en los que la afección principal está considerada también como comorbilidad
contador
# Out:
# 134018

# %%
#Ahora sí obtenemos el número real de comorbilidades
egresos['NUMAFEC'] = egresos['ID'].apply(lambda x: len(diccionario.get(x, [])))

# %%
egresos['NUMAFEC'].value_counts()
# Out:
# 0     192552
# 1      87863
# 2      21223
# 3      10771
# 4       5040
# 5       2350
# 6        986
# 7         96
# 8         13
# 9          2
# 10         1
# Name: NUMAFEC, dtype: int64

# %% [markdown]
# ### Grupo de edad al que pertenece el paciente
#
# Crear una nueva columna en donde se puedan agrupar los pacientes por rango de edad

# %%
# Crear una lista con las condiciones
conditions = [
     (egresos['EDAD'] <= 4),
     (egresos['EDAD'] > 4) & (egresos['EDAD'] <= 14),
     (egresos['EDAD'] > 14) & (egresos['EDAD'] <= 29),
     (egresos['EDAD'] > 29) & (egresos['EDAD'] <= 44),
     (egresos['EDAD'] > 44) & (egresos['EDAD'] <= 59),
     (egresos['EDAD'] > 59)]

# Crear una lista con los valores que le queremos asignar a cada condición
values = ['0 a 4', '5 a 14', '15 a 29', '30 a 44', '45 a 59', '60 o más']

# Crear una nueva columna y usar np.select para asignar los valores especificados
egresos['CAT_EDAD'] = np.select(conditions, values)

egresos.head()
# Out:
#    ID                               CLUES      INGRE     EGRESO  DIAS_ESTA  \
# 0   1  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 1   3  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 2   4  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 3   5  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 4   8  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
#
#   CVEEDAD  EDAD NACIOEN SEXO   PESO  ...            PROCED  \
# 0   MESES     2      NO    M  999.0  ...  CONSULTA EXTERNA
# 1    AÑOS     6     NaN    H  999.0  ...  CONSULTA EXTERNA
# 2    AÑOS     5     NaN    H  999.0  ...  CONSULTA EXTERNA
# 3    AÑOS    18     NaN    H  999.0  ...  CONSULTA EXTERNA
# 4    AÑOS    17     NaN    M  999.0  ...  CONSULTA EXTERNA
#
#                                             DIAG_INI  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...
# 1                                  LEUCEMIA LINFOIDE
# 2                                  LEUCEMIA LINFOIDE
# 3                           ENFERMEDAD RENAL CRÓNICA
# 4                           ENFERMEDAD RENAL CRÓNICA
#
#                                             AFECPRIN          VEZ CAUSAEXT  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...  SUBSECUENTE      NaN
# 1                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 2                                  LEUCEMIA LINFOIDE  SUBSECUENTE      NaN
# 3                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
# 4                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE      NaN
#
#   INFEC  MOTEGRE NUMPROMED NUMAFEC CAT_EDAD
# 0    NO  MEJORIA       1.0       0    0 a 4
# 1    NO  MEJORIA       1.0       0   5 a 14
# 2    NO  MEJORIA       1.0       0   5 a 14
# 3    NO  MEJORIA       1.0       0  15 a 29
# 4    NO  MEJORIA       1.0       0  15 a 29
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Grupo de estancia a la que pertenece el paciente
#
# Crear una nueva columna en donde se puedan agrupar los pacientes por rango de estancia

# %%
# Crear una lista con las condiciones
conditions = [
     (egresos['DIAS_ESTA'] <= 1),
     (egresos['DIAS_ESTA'] > 1) & (egresos['DIAS_ESTA'] <= 3),
     (egresos['DIAS_ESTA'] > 3) & (egresos['DIAS_ESTA'] <= 7),
     (egresos['DIAS_ESTA'] > 7) & (egresos['DIAS_ESTA'] <= 30),
    (egresos['DIAS_ESTA'] > 30)]

# Crear una lista con los valores que le queremos asignar a cada condición
values = ['1 o menos', '2 a 3', '4 a 7', '8 a 30', 'Más de 30']

# Crear una nueva columna y usar np.select para asignar los valores especificados
egresos['CAT_DIASESTA'] = np.select(conditions, values)

egresos.head()
# Out:
#    ID                               CLUES      INGRE     EGRESO  DIAS_ESTA  \
# 0   1  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 1   3  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 2   4  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 3   5  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 4   8  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
#
#   CVEEDAD  EDAD NACIOEN SEXO   PESO  ...  \
# 0   MESES     2      NO    M  999.0  ...
# 1    AÑOS     6     NaN    H  999.0  ...
# 2    AÑOS     5     NaN    H  999.0  ...
# 3    AÑOS    18     NaN    H  999.0  ...
# 4    AÑOS    17     NaN    M  999.0  ...
#
#                                             DIAG_INI  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...
# 1                                  LEUCEMIA LINFOIDE
# 2                                  LEUCEMIA LINFOIDE
# 3                           ENFERMEDAD RENAL CRÓNICA
# 4                           ENFERMEDAD RENAL CRÓNICA
#
#                                             AFECPRIN          VEZ  CAUSAEXT  \
# 0  TUMOR MALIGNO DE OTROS TEJIDOS CONJUNTIVOS Y D...  SUBSECUENTE       NaN
# 1                                  LEUCEMIA LINFOIDE  SUBSECUENTE       NaN
# 2                                  LEUCEMIA LINFOIDE  SUBSECUENTE       NaN
# 3                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE       NaN
# 4                           ENFERMEDAD RENAL CRÓNICA  SUBSECUENTE       NaN
#
#   INFEC  MOTEGRE NUMPROMED NUMAFEC CAT_EDAD CAT_DIASESTA
# 0    NO  MEJORIA       1.0       0    0 a 4    1 o menos
# 1    NO  MEJORIA       1.0       0   5 a 14    1 o menos
# 2    NO  MEJORIA       1.0       0   5 a 14    1 o menos
# 3    NO  MEJORIA       1.0       0  15 a 29    1 o menos
# 4    NO  MEJORIA       1.0       0  15 a 29    1 o menos
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Presencia de diabetes, hipertensión y obesidad
#
# Crear 3 columnas distintas para Diabetes, Hipertensión y Obesidad, asignar el valor 'SI' en caso que el paciente padezca la enfermedad y 'NO' en caso contrario

# %%
# Crear la columna 'DIABETES', 'HIPERTENSION' y 'OBESIDAD' en 'egresos' a partir de la tabla 'afecciones'
egresos['DIABETES'] = egresos['ID'].isin(afecciones.loc[afecciones['AFEC'] == 'DIABETES MELLITUS TIPO 2', 'ID']).map({True: 'SI', False: 'NO'})
egresos['HIPERTENSION'] = egresos['ID'].isin(afecciones.loc[afecciones['AFEC'] == 'HIPERTENSIÓN ESENCIAL (PRIMARIA)', 'ID']).map({True: 'SI', False: 'NO'})
egresos['OBESIDAD'] = egresos['ID'].isin(afecciones.loc[afecciones['AFEC'] == 'OBESIDAD', 'ID']).map({True: 'SI', False: 'NO'})

# %%
egresos.columns
# Out:
# Index(['ID', 'CLUES', 'INGRE', 'EGRESO', 'DIAS_ESTA', 'CVEEDAD', 'EDAD',
#        'NACIOEN', 'SEXO', 'PESO', 'TALLA', 'DERHAB', 'MUNIC', 'LOC', 'TIPSERV',
#        'PROCED', 'DIAG_INI', 'AFECPRIN', 'VEZ', 'CAUSAEXT', 'INFEC', 'MOTEGRE',
#        'NUMPROMED', 'NUMAFEC', 'CAT_EDAD', 'CAT_DIASESTA', 'DIABETES',
#        'HIPERTENSION', 'OBESIDAD'],
#       dtype='object')

# %%
# Cambiar el valor asignado a las columnas en caso que la afección principal o el diagnóstico contengan estas enfermedades
egresos.loc[(egresos['AFECPRIN'] == 'DIABETES MELLITUS TIPO 2') & (egresos['DIABETES'] == 'NO'), 'DIABETES'] = 'SI'
egresos.loc[(egresos['AFECPRIN'] == 'HIPERTENSIÓN ESENCIAL (PRIMARIA)') & (egresos['HIPERTENSION'] == 'NO'), 'HIPERTENSION'] = 'SI'
egresos.loc[(egresos['AFECPRIN'] == 'OBESIDAD') & (egresos['OBESIDAD'] == 'NO'), 'OBESIDAD'] = 'SI'
egresos.loc[(egresos['DIAG_INI'] == 'DIABETES MELLITUS TIPO 2') & (egresos['DIABETES'] == 'NO'), 'DIABETES'] = 'SI'
egresos.loc[(egresos['DIAG_INI'] == 'HIPERTENSIÓN ESENCIAL (PRIMARIA)') & (egresos['HIPERTENSION'] == 'NO'), 'HIPERTENSION'] = 'SI'
egresos.loc[(egresos['DIAG_INI'] == 'OBESIDAD') & (egresos['OBESIDAD'] == 'NO'), 'OBESIDAD'] = 'SI'

# %% [markdown]
# ## Filtrar registros

# %%
# Número total de registros 2010-2022
len(egresos)
# Out:
# 320897

# %%
# Revisar rangos de las edades que están expresadas en horas
egresos[egresos['CVEEDAD']=='HORAS'].describe()
# Out:
#                   ID    DIAS_ESTA         EDAD         PESO        TALLA  \
# count    3147.000000  3147.000000  3147.000000  3147.000000  3147.000000
# mean   156265.399746     8.955513     2.674929   632.688755   643.444550
# std     92949.096944    13.208121     3.780216   480.484521   460.394712
# min      1411.000000     0.000000     1.000000     0.710000    20.000000
# 25%     69918.500000     2.000000     1.000000     3.000000    50.000000
# 50%    157785.000000     4.000000     1.000000   999.000000   999.000000
# 75%    232837.500000     9.500000     2.000000   999.000000   999.000000
# max    321111.000000   129.000000    23.000000   999.000000   999.000000
#
#                LOC    NUMPROMED      NUMAFEC
# count  3147.000000  3147.000000  3147.000000
# mean    549.008580     1.623451     1.152844
# std    2245.904554     1.608226     1.275905
# min       1.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000
# 50%       1.000000     2.000000     1.000000
# 75%       3.000000     3.000000     2.000000
# max    9999.000000    15.000000    10.000000

# %%
# Revisar rangos de las edades que están expresadas en días
egresos[egresos['CVEEDAD']=='DIAS'].describe()
# Out:
#                   ID   DIAS_ESTA         EDAD         PESO        TALLA  \
# count    8193.000000  8193.00000  8193.000000  8193.000000  8193.000000
# mean   159071.583791     8.85805     7.778103   671.002231   690.502380
# std     88134.492693    17.39346     7.614351   468.125451   444.851218
# min       353.000000     0.00000     1.000000     0.580000    20.000000
# 25%     81755.000000     3.00000     2.000000     3.300000    51.000000
# 50%    157342.000000     5.00000     5.000000   999.000000   999.000000
# 75%    233098.000000    10.00000    11.000000   999.000000   999.000000
# max    321131.000000  1110.00000    29.000000   999.000000   999.000000
#
#                LOC    NUMPROMED      NUMAFEC
# count  8193.000000  8193.000000  8193.000000
# mean    245.220066     2.207128     1.121811
# std    1512.634596     1.366518     1.178752
# min       1.000000     0.000000     0.000000
# 25%       1.000000     1.000000     0.000000
# 50%       1.000000     2.000000     1.000000
# 75%       1.000000     3.000000     2.000000
# max    9999.000000    11.000000     7.000000

# %%
# Revisar rangos de las edades que están expresadas en meses
egresos[egresos['CVEEDAD']=='MESES'].describe()
# Out:
#                   ID     DIAS_ESTA          EDAD          PESO         TALLA  \
# count   11000.000000  11000.000000  11000.000000  11000.000000  11000.000000
# mean   144123.231455      6.663000      4.851273    876.565978    891.758364
# std     86950.985700     12.387564      3.150333    326.529734    298.614782
# min         1.000000      0.000000      1.000000      0.840000     21.000000
# 25%     73796.500000      1.000000      2.000000    999.000000    999.000000
# 50%    143374.500000      4.000000      4.000000    999.000000    999.000000
# 75%    214232.000000      7.000000      7.000000    999.000000    999.000000
# max    321198.000000    448.000000     11.000000    999.000000    999.000000
#
#                 LOC     NUMPROMED       NUMAFEC
# count  11000.000000  11000.000000  11000.000000
# mean     116.732909      1.973455      0.930455
# std      988.018192      1.273573      1.175321
# min        1.000000      0.000000      0.000000
# 25%        1.000000      1.000000      0.000000
# 50%        1.000000      2.000000      1.000000
# 75%        1.000000      3.000000      1.000000
# max     9999.000000     16.000000      9.000000

# %%
# Cambiar edades de pacientes menores a 1 año por edad 0
egresos['EDAD'] = np.where(egresos['CVEEDAD'] != 'AÑOS', 0, egresos['EDAD'])
egresos.head(20)
# Out:
#     ID                               CLUES      INGRE     EGRESO  DIAS_ESTA  \
# 0    1  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 1    3  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 2    4  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 3    5  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 4    8  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 5   10  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 6   12  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 7   14  CENTENARIO HOSPITAL MIGUEL HIDALGO 2009-12-28 2010-01-01          4
# 8   19  CENTENARIO HOSPITAL MIGUEL HIDALGO 2009-12-06 2010-01-05         30
# 9   21  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 10  22  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-03 2010-01-04          1
# 11  23  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 12  24  CENTENARIO HOSPITAL MIGUEL HIDALGO 2009-12-31 2010-01-08          8
# 13  26  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-06 2010-01-06          1
# 14  27  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 15  28  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-05 2010-01-05          1
# 16  29  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-01 2010-01-01          1
# 17  30  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-03 2010-01-05          2
# 18  38  CENTENARIO HOSPITAL MIGUEL HIDALGO 2010-01-04 2010-01-04          1
# 19  40  CENTENARIO HOSPITAL MIGUEL HIDALGO 2009-12-31 2010-01-01          1
#
#    CVEEDAD  EDAD NACIOEN SEXO   PESO  ...  CAUSAEXT INFEC  MOTEGRE  NUMPROMED  \
# 0    MESES     0      NO    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 1     AÑOS     6     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 2     AÑOS     5     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 3     AÑOS    18     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 4     AÑOS    17     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 5     AÑOS     4     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 6     AÑOS    12     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 7     AÑOS     4     NaN    H  999.0  ...       NaN    NO  MEJORIA        3.0
# 8    MESES     0     NaN    M  999.0  ...       NaN    NO  MEJORIA        2.0
# 9     AÑOS     5     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 10    AÑOS    72     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 11    AÑOS    25     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 12    AÑOS    79     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 13    AÑOS     5     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 14    AÑOS    45     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 15    AÑOS    21     NaN    H  999.0  ...       NaN    NO  MEJORIA        1.0
# 16    AÑOS    15     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 17    AÑOS    10     NaN    H  999.0  ...       NaN    NO  MEJORIA        4.0
# 18    AÑOS    50     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
# 19    AÑOS    44     NaN    M  999.0  ...       NaN    NO  MEJORIA        1.0
#
#    NUMAFEC  CAT_EDAD CAT_DIASESTA DIABETES HIPERTENSION OBESIDAD
# 0        0     0 a 4    1 o menos       NO           NO       NO
# 1        0    5 a 14    1 o menos       NO           NO       NO
# 2        0    5 a 14    1 o menos       NO           NO       NO
# 3        0   15 a 29    1 o menos       NO           NO       NO
# 4        0   15 a 29    1 o menos       NO           NO       NO
# 5        0     0 a 4    1 o menos       NO           NO       NO
# 6        0    5 a 14    1 o menos       NO           NO       NO
# 7        0     0 a 4        4 a 7       NO           NO       NO
# 8        0    5 a 14       8 a 30       NO           NO       NO
# 9        0    5 a 14    1 o menos       NO           NO       NO
# 10       0  60 o más    1 o menos       NO           NO       NO
# 11       0   15 a 29    1 o menos       NO           NO       NO
# 12       0  60 o más       8 a 30       NO           NO       NO
# 13       0    5 a 14    1 o menos       NO           NO       NO
# 14       0   45 a 59    1 o menos       NO           NO       NO
# 15       0   15 a 29    1 o menos       NO           NO       NO
# 16       0   15 a 29    1 o menos       NO           NO       NO
# 17       1    5 a 14        2 a 3       NO           NO       NO
# 18       0   45 a 59    1 o menos       NO           NO       NO
# 19       0   30 a 44    1 o menos       NO           NO       NO
#
# [20 rows x 29 columns]

# %%
egresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320897 entries, 0 to 320896
# Data columns (total 29 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            320897 non-null  int64
#  1   CLUES         320897 non-null  object
#  2   INGRE         320897 non-null  datetime64[ns]
#  3   EGRESO        320897 non-null  datetime64[ns]
#  4   DIAS_ESTA     320897 non-null  int64
#  5   CVEEDAD       320896 non-null  object
#  6   EDAD          320897 non-null  int64
#  7   NACIOEN       15960 non-null   object
#  8   SEXO          320897 non-null  object
#  9   PESO          320897 non-null  float64
#  10  TALLA         320897 non-null  float64
#  11  DERHAB        320897 non-null  object
#  12  MUNIC         320897 non-null  object
#  13  LOC           320897 non-null  int64
#  14  TIPSERV       320894 non-null  object
#  15  PROCED        320896 non-null  object
#  16  DIAG_INI      320895 non-null  object
#  17  AFECPRIN      320894 non-null  object
#  18  VEZ           320896 non-null  object
#  19  CAUSAEXT      30440 non-null   object
#  20  INFEC         320895 non-null  object
#  21  MOTEGRE       320896 non-null  object
#  22  NUMPROMED     320897 non-null  float64
#  23  NUMAFEC       320897 non-null  int64
#  24  CAT_EDAD      320897 non-null  object
#  25  CAT_DIASESTA  320897 non-null  object
#  26  DIABETES      320897 non-null  object
#  27  HIPERTENSION  320897 non-null  object
#  28  OBESIDAD      320897 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(5), object(19)
# memory usage: 73.4+ MB

# %%
#Cambiar tipo de dato de NUMPROMED a entero
egresos['NUMPROMED'] = egresos['NUMPROMED'].astype('int64')
egresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320894 entries, 0 to 320896
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            320894 non-null  int64
#  1   CLUES         320894 non-null  object
#  2   INGRE         320894 non-null  datetime64[ns]
#  3   EGRESO        320894 non-null  datetime64[ns]
#  4   DIAS_ESTA     320894 non-null  int64
#  5   EDAD          320894 non-null  int64
#  6   SEXO          320894 non-null  object
#  7   PESO          320894 non-null  float64
#  8   TALLA         320894 non-null  float64
#  9   DERHAB        320894 non-null  object
#  10  MUNIC         320894 non-null  object
#  11  TIPSERV       320894 non-null  object
#  12  PROCED        320894 non-null  object
#  13  DIAG_INI      320894 non-null  object
#  14  AFECPRIN      320894 non-null  object
#  15  VEZ           320894 non-null  object
#  16  CAUSAEXT      320894 non-null  object
#  17  INFEC         320894 non-null  object
#  18  MOTEGRE       320894 non-null  object
#  19  NUMPROMED     320894 non-null  int64
#  20  NUMAFEC       320894 non-null  int64
#  21  CAT_EDAD      320894 non-null  object
#  22  CAT_DIASESTA  320894 non-null  object
#  23  DIABETES      320894 non-null  object
#  24  HIPERTENSION  320894 non-null  object
#  25  OBESIDAD      320894 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(5), object(17)
# memory usage: 66.1+ MB

# %%
#Eliminar nulos de columnas de egresos
egresos.dropna(subset=['CVEEDAD', 'TIPSERV', 'PROCED', 'DIAG_INI', 'AFECPRIN',
                       'VEZ', 'INFEC', 'MOTEGRE'], inplace=True)

# %%
#Solo se eliminan 3 registros, por lo que no se pierde mucha información
len(egresos)
# Out:
# 320894

# %%
#Eliminar columnas que no nos sirven
#NACIOEN sólo indica si, en caso de ser recién nacido, nació en el hospital o no, por lo que tiene muchos nulos
#LOC es la localidad en la que reside el paciente, pero son demasiadas, por lo que solo nos quedamos con el Municipio
#CVEEDAD ya no nos da información porque ya todas las edades están expresadas en años
egresos = egresos.drop(['NACIOEN', 'LOC','CVEEDAD'], axis = 1)

# %%
# Llenar los valores nulos en la columna CAUSAEXT con 'NO APLICA' ya que son pacientes que no tienen lesión
egresos['CAUSAEXT'] = egresos['CAUSAEXT'].fillna('NO APLICA')

# %%
#Comprobamos que ya no tenemos valores nulos
egresos.isnull().sum()
# Out:
# ID              0
# CLUES           0
# INGRE           0
# EGRESO          0
# DIAS_ESTA       0
# EDAD            0
# SEXO            0
# PESO            0
# TALLA           0
# DERHAB          0
# MUNIC           0
# TIPSERV         0
# PROCED          0
# DIAG_INI        0
# AFECPRIN        0
# VEZ             0
# CAUSAEXT        0
# INFEC           0
# MOTEGRE         0
# NUMPROMED       0
# NUMAFEC         0
# CAT_EDAD        0
# CAT_DIASESTA    0
# DIABETES        0
# HIPERTENSION    0
# OBESIDAD        0
# dtype: int64

# %% [markdown]
# ## Exploración inicial

# %% [markdown]
# ### Egresos

# %%
egresos.info()

# %%
egresos.describe()
# Out:
#                   ID      DIAS_ESTA           EDAD           PESO  \
# count  320894.000000  320894.000000  320894.000000  320894.000000
# mean   160803.790005       3.102897      30.945957     852.253243
# std     92653.293244       8.125905      23.264736     340.954951
# min         1.000000       0.000000       0.000000       0.580000
# 25%     80592.250000       1.000000      14.000000     999.000000
# 50%    160815.500000       1.000000      26.000000     999.000000
# 75%    241038.750000       3.000000      46.000000     999.000000
# max    321262.000000    1838.000000     130.000000     999.000000
#
#                TALLA     NUMPROMED        NUMAFEC
# count  320894.000000  320894.00000  320894.000000
# mean      871.367090       1.61717       0.627151
# std       304.843539       1.22473       1.005071
# min        15.000000       0.00000       0.000000
# 25%       999.000000       1.00000       0.000000
# 50%       999.000000       1.00000       0.000000
# 75%       999.000000       2.00000       1.000000
# max       999.000000      77.00000      10.000000

# %% [markdown]
# ### Afecciones

# %%
afecciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305047 entries, 0 to 305046
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       305047 non-null  int64
#  1   NUMAFEC  305047 non-null  int64
#  2   AFEC     305047 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 7.0+ MB

# %%
afecciones.describe()
# Out:
#                   ID        NUMAFEC
# count  335485.000000  335485.000000
# mean   186890.008260       1.636854
# std     86740.347783       1.071359
# min         6.000000       1.000000
# 25%    125992.000000       1.000000
# 50%    197172.000000       1.000000
# 75%    259366.000000       2.000000
# max    321262.000000      10.000000

# %% [markdown]
# ### Procedimientos

# %%
procedimientos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519460 entries, 0 to 519459
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         519460 non-null  int64
#  1   NUMPROMED  519460 non-null  int64
#  2   TIPO       519460 non-null  object
#  3   PROMED     519460 non-null  object
#  4   ANEST      519460 non-null  object
#  5   QUIROF     519460 non-null  object
#  6   QH         238223 non-null  float64
#  7   QM         238182 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 31.7+ MB

# %%
procedimientos.isnull().sum()
# Out:
# ID                0
# NUMPROMED         0
# TIPO              0
# PROMED            0
# ANEST             0
# QUIROF            0
# QH           281237
# QM           281278
# dtype: int64

# %%
#Revisar si hay registros nulos para el tiempo de quirófano cuando efectivamente se haya usado el quirófano
df = procedimientos[procedimientos['QUIROF']=='EN']
df.isnull().sum()
# Out:
# ID            0
# NUMPROMED     0
# TIPO          0
# PROMED        0
# ANEST         0
# QUIROF        0
# QH            1
# QM           42
# dtype: int64

# %%
#Asignar un valor de 0 a los registros nulos en donde no se usó quirófano
procedimientos.loc[(procedimientos['QUIROF'] != 'EN') & 
                   ((procedimientos['QH'].isnull()) | (procedimientos['QM'].isnull())), ['QH', 'QM']] = 0
#Comprobamos que los únicos valores que quedan nulos corresponden a pacientes que ingresaron al quirófano
procedimientos.isnull().sum()
# Out:
# ID            0
# NUMPROMED     0
# TIPO          0
# PROMED        0
# ANEST         0
# QUIROF        0
# QH            1
# QM           42
# dtype: int64

# %%
df[df['QH'].isnull()]
# Out:
#             ID  NUMPROMED         TIPO  \
# 423205  275551          4  DIAGNOSTICO
#
#                                                    PROMED    ANEST QUIROF  QH  \
# 423205  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...  GENERAL     EN NaN
#
#         QM
# 423205 NaN

# %%
#En general para este procedimiento no tenemos valores de tiempo en quirófano (99 es NE, 0 no es un valor real)
df[df['PROMED']=='PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCICA, PLEURA, MEDIASTINO Y DIAFRAGMA']
# Out:
#             ID  NUMPROMED         TIPO  \
# 3088      2879          5  DIAGNOSTICO
# 36048     2724          1  DIAGNOSTICO
# 36055     2803          6  DIAGNOSTICO
# 56566    36661          1  DIAGNOSTICO
# 61846    32139          2  DIAGNOSTICO
# ...        ...        ...          ...
# 465497  287581          2  DIAGNOSTICO
# 465498  287581          3  DIAGNOSTICO
# 465587  287439          1  DIAGNOSTICO
# 465653  298023          3  DIAGNOSTICO
# 473421  300295          1  DIAGNOSTICO
#
#                                                    PROMED     ANEST QUIROF  \
# 3088    PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 36048   PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 36055   PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 56566   PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...  REGIONAL     EN
# 61846   PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...  REGIONAL     EN
# ...                                                   ...       ...    ...
# 465497  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 465498  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 465587  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 465653  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
# 473421  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   GENERAL     EN
#
#           QH    QM
# 3088    99.0  99.0
# 36048   99.0  99.0
# 36055   99.0  99.0
# 56566   99.0  99.0
# 61846   99.0  99.0
# ...      ...   ...
# 465497   0.0   0.0
# 465498   0.0   0.0
# 465587   0.0   0.0
# 465653   0.0   0.0
# 473421   0.0   1.0
#
# [97 rows x 8 columns]

# %%
#Vemos que hay un registro de solo 1 minuto, probablemente se equivocaron y era 1 hora
df[(df['PROMED']=='PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCICA, PLEURA, MEDIASTINO Y DIAFRAGMA')
  & (((df['QH']>0) & (df['QH']<99)) | ((df['QM']>0) & (df['QM']<99)))]
# Out:
#             ID  NUMPROMED         TIPO  \
# 141434   98683          5  DIAGNOSTICO
# 142498   99226          3  DIAGNOSTICO
# 182256  114856          3  DIAGNOSTICO
# 216453  148268          4  DIAGNOSTICO
# 284844  196031          1  DIAGNOSTICO
# 317014  220453          3  DIAGNOSTICO
# 320502  215717          2  DIAGNOSTICO
# 327710  223666          1  DIAGNOSTICO
# 328583  226027          2  DIAGNOSTICO
# 331276  223086          2  DIAGNOSTICO
# 371390  251608          3  DIAGNOSTICO
# 386728  250844          3  DIAGNOSTICO
# 405989  266400          1  DIAGNOSTICO
# 410152  269277          4  DIAGNOSTICO
# 420243  274901          5  DIAGNOSTICO
# 420246  274901          4  DIAGNOSTICO
# 452426  297894          1  DIAGNOSTICO
# 454836  288640          3  DIAGNOSTICO
# 455647  298000          1  DIAGNOSTICO
# 473421  300295          1  DIAGNOSTICO
#
#                                                    PROMED      ANEST QUIROF  \
# 141434  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   REGIONAL     EN
# 142498  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...      LOCAL     EN
# 182256  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   REGIONAL     EN
# 216453  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   REGIONAL     EN
# 284844  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 317014  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 320502  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...  COMBINADA     EN
# 327710  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   REGIONAL     EN
# 328583  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...   REGIONAL     EN
# 331276  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 371390  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...  COMBINADA     EN
# 386728  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 405989  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 410152  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 420243  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 420246  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 452426  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...  COMBINADA     EN
# 454836  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 455647  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
# 473421  PROCEDIMIENTOS DIAGNÓSTICOS SOBRE PARED TORÁCI...    GENERAL     EN
#
#          QH    QM
# 141434  0.0  30.0
# 142498  0.0  30.0
# 182256  1.0   0.0
# 216453  0.0  30.0
# 284844  1.0   0.0
# 317014  2.0  30.0
# 320502  1.0   0.0
# 327710  1.0   0.0
# 328583  1.0   0.0
# 331276  1.0   0.0
# 371390  0.0  50.0
# 386728  2.0   0.0
# 405989  1.0   0.0
# 410152  0.0  20.0
# 420243  0.0  30.0
# 420246  0.0  30.0
# 452426  1.0   0.0
# 454836  2.0   0.0
# 455647  2.0   0.0
# 473421  0.0   1.0

# %%
#También hay muchas cirugías donde no se pone tiempo
df[(df['QH']==0)&(df['QM']==0)]
# Out:
#             ID  NUMPROMED         TIPO  \
# 313601  218285          1   QUIRURGICO
# 313602  220519          1   QUIRURGICO
# 313603  214528          1   QUIRURGICO
# 313604  217543          1  DIAGNOSTICO
# 313605  219754          1  DIAGNOSTICO
# ...        ...        ...          ...
# 469502  291325          1   QUIRURGICO
# 469504  291323          1  DIAGNOSTICO
# 469505  291323          2   QUIRURGICO
# 469506  291323          3   QUIRURGICO
# 469507  291322          1   QUIRURGICO
#
#                                                    PROMED     ANEST QUIROF  \
# 313601  SUSTITUCIÓN DE LAS ARTICULACIONES DE LAS EXTRE...  REGIONAL     EN
# 313602  REDUCCIÓN ABIERTA DE FRACTURA CON FIJACIÓN INT...   GENERAL     EN
# 313603                                TIROIDECTOMÍA TOTAL   GENERAL     EN
# 313604            PROCEDIMIENTOS DIAGNÓSTICOS SOBRE RIÑÓN     LOCAL     EN
# 313605          PROCEDIMIENTOS DIAGNÓSTICOS SOBRE ESÓFAGO   GENERAL     EN
# ...                                                   ...       ...    ...
# 469502                                     HIPOFISECTOMÍA   GENERAL     EN
# 469504             PROCEDIMIENTOS DIAGNÓSTICOS SOBRE MAMA  SEDACION     EN
# 469505     EXTIRPACIÓN O DESTRUCCIÓN DE TEJIDO DE LA MAMA  SEDACION     EN
# 469506   SUTURA U OTRO CIERRE DE PIEL Y TEJIDO SUBCUTÁNEO  SEDACION     EN
# 469507  REPARACIÓN DE OTRA HERNIA DE LA PARED ABDOMINA...  SEDACION     EN
#
#          QH   QM
# 313601  0.0  0.0
# 313602  0.0  0.0
# 313603  0.0  0.0
# 313604  0.0  0.0
# 313605  0.0  0.0
# ...     ...  ...
# 469502  0.0  0.0
# 469504  0.0  0.0
# 469505  0.0  0.0
# 469506  0.0  0.0
# 469507  0.0  0.0
#
# [21063 rows x 8 columns]

# %%
#También hay procedimientos que duran muy pocos minutos, algunos es posible, pero otros no
df[(df['QH']==0)&(df['QM']<10)&(df['QM']>0)]
# Out:
#             ID  NUMPROMED         TIPO  \
# 313944  221333          1   QUIRURGICO
# 316778  217460          1   QUIRURGICO
# 318697  220345          1   QUIRURGICO
# 320201  217679          1   QUIRURGICO
# 320202  217679          2   QUIRURGICO
# ...        ...        ...          ...
# 519180  321202          3  TERAPEUTICO
# 519310  321230          2   QUIRURGICO
# 519328  321235          1   QUIRURGICO
# 519403  321251          5  TERAPEUTICO
# 519428  321256          2   QUIRURGICO
#
#                                                    PROMED     ANEST QUIROF  \
# 313944                     LOBECTOMÍA TIROIDEA UNILATERAL   GENERAL     EN
# 316778                                     APENDICECTOMÍA  REGIONAL     EN
# 318697  EXTRACCIÓN EXTRACAPSULAR DE CRISTALINO MEDIANT...  SEDACION     EN
# 320201                    EXTRACCIÓN QUIRÚRGICA DE DIENTE   GENERAL     EN
# 320202                    EXTRACCIÓN QUIRÚRGICA DE DIENTE   GENERAL     EN
# ...                                                   ...       ...    ...
# 519180  INYECCIÓN O INFUSIÓN DE OTRA SUSTANCIA TERAPÉU...    NO USO     EN
# 519310  EXPLORACIÓN MANUAL DE LA CAVIDAD UTERINA, DESP...    NO USO     EN
# 519328  EXPLORACIÓN MANUAL DE LA CAVIDAD UTERINA, DESP...    NO USO     EN
# 519403  PROCEDIMIENTOS QUE REDUCEN LA MORBILIDAD Y LA ...     LOCAL     EN
# 519428  EXPLORACIÓN MANUAL DE LA CAVIDAD UTERINA, DESP...     LOCAL     EN
#
#          QH   QM
# 313944  0.0  5.0
# 316778  0.0  1.0
# 318697  0.0  4.0
# 320201  0.0  5.0
# 320202  0.0  2.0
# ...     ...  ...
# 519180  0.0  1.0
# 519310  0.0  5.0
# 519328  0.0  1.0
# 519403  0.0  1.0
# 519428  0.0  1.0
#
# [1987 rows x 8 columns]

# %%
#Hay muchos valores erróneos, no es posible checar cada procedimiento para ver si tiene un valor lógico o no
#Eliminamos las columnas para no tener problemas
procedimientos = procedimientos.drop(['QH', 'QM'], axis = 1)
procedimientos.head()
# Out:
#       ID  NUMPROMED        TIPO       PROMED     ANEST QUIROF
# 0  10952          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN
# 1  23436          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN
# 2  23659          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN
# 3  23789          1  QUIRURGICO  LAPAROTOMÍA   GENERAL     EN
# 4  24367          1  QUIRURGICO  LAPAROTOMÍA  REGIONAL     EN

# %% [markdown]
# ## Exportar csv

# %%
from pathlib import Path 
#Egresos
filepath = Path('../../Registros/Bases de datos/2010_2022/Cambio claves/Antes de graficar/egresos.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
egresos.to_csv(filepath, index = False)

# %%
#Procedimientos
filepath = Path('../../Registros/Bases de datos/2010_2022/Cambio claves/Antes de graficar/procedimientos.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
procedimientos.to_csv(filepath, index = False)

# %%
#Afecciones
filepath = Path('../../Registros/Bases de datos/2010_2022/Cambio claves/Antes de graficar/afecciones.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
afecciones.to_csv(filepath, index = False)
