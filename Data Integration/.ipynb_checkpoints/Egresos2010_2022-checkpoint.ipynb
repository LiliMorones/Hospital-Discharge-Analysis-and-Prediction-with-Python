# %% [markdown]
# # Discharges Data Integration  2010-2022

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load databases from Discharges

# %%
file = '../../Data/Databases/Data Integration/egresos2010_2013.csv'
e10_13 = pd.read_csv(file, on_bad_lines='skip')
e10_13.head()
# Out:
# C:\Users\lili_\AppData\Local\Temp\ipykernel_12252\1413136596.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   e10_13 = pd.read_csv(file, on_bad_lines='skip')
#    ID2        CLUES      EGRESO       INGRE  DIAS_ESTA  CVEEDAD  EDAD  \
# 0    1  ASSSA000025  04/01/2010  04/01/2010        1.0      2.0   2.0
# 1    2  ASSSA000025  30/12/2009  30/12/2009        1.0      3.0   5.0
# 2    3  ASSSA000025  06/01/2010  06/01/2010        1.0      3.0   6.0
# 3    4  ASSSA000025  05/01/2010  05/01/2010        1.0      3.0   5.0
# 4    5  ASSSA000025  04/01/2010  04/01/2010        1.0      3.0  18.0
#
#    NACIOEN  SEXO   PESO  ...  MUNIC  LOC  TIPSERV  PROCED  MOTEGRE  DIAG_INI  \
# 0      2.0   2.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      C492
# 1      NaN   2.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      C910
# 2      NaN   1.0  999.0  ...    2.0  3.0      1.0     1.0      2.0      C910
# ...

# %%
file = '../../Data/Databases/Data Integration/egresos2014_2015.csv'
e14_15 = pd.read_csv(file, on_bad_lines='skip')
e14_15.head()
# Out:
#       ID2        CLUES               EGRESO                INGRE  DIAS_ESTA  \
# 0  108363  ASSSA000025  2013-12-26 00:00:00  2013-12-25 00:00:00          1
# 1  108364  ASSSA000025  2013-12-27 00:00:00  2013-12-26 00:00:00          1
# 2  108365  ASSSA000025  2014-01-07 00:00:00  2014-01-06 00:00:00          1
# 3  108366  ASSSA000025  2014-01-07 00:00:00  2014-01-06 00:00:00          1
# 4  108367  ASSSA000025  2014-01-07 00:00:00  2014-01-06 00:00:00          1
#
#    CVEEDAD  EDAD  NACIOEN  SEXO  PESO  ...  MUNIC  LOC  TIPSERV  PROCED  \
# 0        3    69      NaN     2   999  ...      1    1        1       1
# 1        3    54      NaN     2   999  ...      1    1        1       1
# 2        3    45      NaN     2   999  ...      1    1        1       1
# 3        3    69      NaN     2   999  ...      2    1        1       1
# 4        3    74      NaN     2   999  ...      5    1        1       1
#
#    MOTEGRE  DIAG_INI  AFECPRIN VEZ INFEC  CAUSAEXT
# ...

# %%
file = '../../Data/Databases/Data Integration/egresos2016_2017.csv'
e16_17 = pd.read_csv(file, on_bad_lines='skip')
e16_17.head()
# Out:
#       ID2        CLUES            EGRESO             INGRE  DIAS_ESTA  \
# 0  161767  ASSSA000025  12/30/2015 00:00  12/30/2015 00:00          1
# 1  161768  ASSSA000025  12/31/2015 00:00  12/31/2015 00:00          1
# 2  161769  ASSSA000025  12/31/2015 00:00  12/31/2015 00:00          1
# 3  161770  ASSSA000025  01/02/2016 00:00  01/02/2016 00:00          1
# 4  161771  ASSSA000025  01/02/2016 00:00  01/02/2016 00:00          1
#
#    CVEEDAD  EDAD  NACIOEN  SEXO   PESO  ...  MUNIC  LOC  TIPSERV  PROCED  \
# 0        3    24      NaN     2  999.0  ...      1    1        1       4
# 1        3    15      NaN     2  999.0  ...      1    1        1       4
# 2        3    24      NaN     2  999.0  ...      1    1        1       4
# 3        3    85      NaN     1  999.0  ...      1    1        1       4
# 4        3    56      NaN     2  999.0  ...     10   12        1       4
#
#    MOTEGRE  DIAG_INI  AFECPRIN VEZ INFEC  CAUSAEXT
# 0        7      N185      N185   2     2       NaN
# ...

# %%
file = '../../Data/Databases/Data Integration/egresos2018_2019.csv'
e18_19 = pd.read_csv(file, on_bad_lines='skip')
e18_19.head()
# Out:
#       ID2        CLUES                   EGRESO                    INGRE  \
# 0  213269  ASSSA000025  2018-03-11 00:00:00.000  2018-03-09 00:00:00.000
# 1  213270  ASSSA000025  2018-03-15 00:00:00.000  2018-03-13 00:00:00.000
# 2  213271  ASSSA000025  2018-04-07 00:00:00.000  2018-04-06 00:00:00.000
# 3  213272  ASSSA000025  2018-04-06 00:00:00.000  2018-04-06 00:00:00.000
# 4  213273  ASSSA000025  2018-04-30 00:00:00.000  2018-04-29 00:00:00.000
#
#    DIAS_ESTA  CVEEDAD  EDAD  NACIOEN  SEXO   PESO  ...  MUNIC LOC  TIPSERV  \
# 0          2        3    19        8     1  999.0  ...      3   1        1
# 1          2        3    49        8     2  999.0  ...      1   1        1
# 2          1        3    77        8     2  999.0  ...      5   1        1
# 3          1        3     1        8     1  999.0  ...      1   1        1
# 4          1        3    83        8     2  999.0  ...      1   1        1
#
#    PROCED  MOTEGRE  DIAG_INI  AFECPRIN VEZ INFEC  CAUSAEXT
# ...

# %%
file = '../../Data/Databases/Data Integration/egresos2020_2021.csv'
e20_21 = pd.read_csv(file, on_bad_lines='skip')
e20_21.head()
# Out:
#       ID2        CLUES                   EGRESO                    INGRE  \
# 0  257456  ASSSA000030  2020-11-20 00:00:00.000  2020-11-19 00:00:00.000
# 1  257457  ASSSA000030  2020-11-20 00:00:00.000  2020-11-10 00:00:00.000
# 2  257458  ASSSA000030  2020-11-20 00:00:00.000  2020-11-18 00:00:00.000
# 3  257459  ASSSA000030  2020-11-20 00:00:00.000  2020-11-15 00:00:00.000
# 4  257460  ASSSA000030  2020-11-20 00:00:00.000  2020-11-08 00:00:00.000
#
#    DIAS_ESTA  CVEEDAD  EDAD  NACIOEN  SEXO   PESO  ...  MUNIC  LOC  TIPSERV  \
# 0        1.0      3.0  15.0      8.0   2.0  999.0  ...    1.0  1.0      1.0
# 1       10.0      3.0  29.0      8.0   1.0   80.0  ...    1.0  1.0      1.0
# 2        2.0      3.0   5.0      8.0   2.0   20.0  ...    1.0  1.0      1.0
# 3        5.0      3.0  45.0      8.0   1.0   40.0  ...    1.0  1.0      1.0
# 4       12.0      3.0  78.0      8.0   1.0   70.0  ...    1.0  1.0      1.0
#
#    PROCED  MOTEGRE  DIAG_INI  AFECPRIN  VEZ INFEC  CAUSAEXT
# ...

# %%
file = '../../Data/Databases/Data Integration/egresos2022.csv'
e22 = pd.read_csv(file, on_bad_lines='skip')
e22.head()
# Out:
#       ID2        CLUES      EGRESO       INGRE  DIAS_ESTA  CVEEDAD  EDAD  \
# 0  298043  ASSSA001331  2022-01-26  2022-01-23          3        3     3
# 1  298044  ASSSA001331  2022-01-26  2022-01-26          1        3     7
# 2  298045  ASSSA001331  2022-01-13  2022-01-13          1        3    10
# 3  298046  ASSSA001331  2022-01-26  2022-01-25          1        3     9
# 4  298047  ASSSA001331  2022-01-26  2022-01-19          7        3    17
#
#    NACIOEN  SEXO   PESO  ...  MUNIC  LOC  TIPSERV  PROCED  MOTEGRE  DIAG_INI  \
# 0        8     1  999.0  ...      1    1        1       2        2      C910
# 1        8     1  999.0  ...      5  427        1       1        2      C64X
# 2        8     2  999.0  ...      7    1        1       1        2      C910
# 3        8     1  999.0  ...      1    1        1       2        2      Q891
# 4        8     1  999.0  ...      1    1        1       2        2      R509
#
#    AFECPRIN VEZ INFEC  CAUSAEXT
# ...

# %% [markdown]
# ## Data Integration

# %%
egresos = pd.concat([e10_13, e14_15, e16_17, e18_19, e20_21, e22])
egresos.head()
# Out:
#    ID2        CLUES      EGRESO       INGRE  DIAS_ESTA  CVEEDAD  EDAD  \
# 0    1  ASSSA000025  04/01/2010  04/01/2010        1.0      2.0   2.0
# 1    2  ASSSA000025  30/12/2009  30/12/2009        1.0      3.0   5.0
# 2    3  ASSSA000025  06/01/2010  06/01/2010        1.0      3.0   6.0
# 3    4  ASSSA000025  05/01/2010  05/01/2010        1.0      3.0   5.0
# 4    5  ASSSA000025  04/01/2010  04/01/2010        1.0      3.0  18.0
#
#    NACIOEN  SEXO   PESO  ...  MUNIC  LOC  TIPSERV  PROCED  MOTEGRE  DIAG_INI  \
# 0      2.0   2.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      C492
# 1      NaN   2.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      C910
# 2      NaN   1.0  999.0  ...    2.0  3.0      1.0     1.0      2.0      C910
# 3      NaN   1.0  999.0  ...   10.0  3.0      1.0     1.0      2.0      C910
# 4      NaN   1.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      N180
#
#    AFECPRIN VEZ INFEC CAUSAEXT
# 0      C492   2   2.0      NaN
# ...

# %% [markdown]
# ## Rename ID column

# %%
egresos.rename(columns={'ID2':'ID'},inplace=True)
egresos.head()
# Out:
#    ID        CLUES      EGRESO       INGRE  DIAS_ESTA  CVEEDAD  EDAD  NACIOEN  \
# 0   1  ASSSA000025  04/01/2010  04/01/2010        1.0      2.0   2.0      2.0
# 1   2  ASSSA000025  30/12/2009  30/12/2009        1.0      3.0   5.0      NaN
# 2   3  ASSSA000025  06/01/2010  06/01/2010        1.0      3.0   6.0      NaN
# 3   4  ASSSA000025  05/01/2010  05/01/2010        1.0      3.0   5.0      NaN
# 4   5  ASSSA000025  04/01/2010  04/01/2010        1.0      3.0  18.0      NaN
#
#    SEXO   PESO  ...  MUNIC  LOC  TIPSERV  PROCED  MOTEGRE  DIAG_INI  AFECPRIN  \
# 0   2.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      C492      C492
# 1   2.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      C910      C910
# 2   1.0  999.0  ...    2.0  3.0      1.0     1.0      2.0      C910      C910
# 3   1.0  999.0  ...   10.0  3.0      1.0     1.0      2.0      C910      C910
# 4   1.0  999.0  ...    1.0  1.0      1.0     1.0      2.0      N180      N180
#
#   VEZ INFEC CAUSAEXT
# ...

# %% [markdown]
# ## Change data types

# %%
egresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 321262 entries, 0 to 23219
# Data columns (total 22 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         321262 non-null  int64
#  1   CLUES      321262 non-null  object
#  2   EGRESO     321262 non-null  object
#  3   INGRE      321262 non-null  object
#  4   DIAS_ESTA  321262 non-null  float64
#  5   CVEEDAD    321261 non-null  float64
#  6   EDAD       321262 non-null  float64
#  7   NACIOEN    119274 non-null  float64
#  8   SEXO       321262 non-null  float64
#  9   PESO       321262 non-null  float64
#  10  TALLA      321262 non-null  float64
#  11  DERHAB     321262 non-null  object
#  12  MUNIC      321262 non-null  float64
#  13  LOC        321262 non-null  float64
#  14  TIPSERV    321260 non-null  float64
#  15  PROCED     321261 non-null  float64
#  16  MOTEGRE    321261 non-null  float64
#  17  DIAG_INI   321262 non-null  object
# ...

# %%
egresos['DIAS_ESTA'] = egresos['DIAS_ESTA'].astype(int)

# %%
egresos['EDAD'] = egresos['EDAD'].astype(int)

# %%
egresos['SEXO'] = egresos['SEXO'].astype(int)

# %%
egresos['MUNIC'] = egresos['MUNIC'].astype(int)

# %%
egresos['LOC'] = egresos['LOC'].astype(int)

# %% [markdown]
# ## Export data to csv

# %%
from pathlib import Path 
filepath = Path('../../Data/Databases/Data Integration/egresos2010_2022.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
egresos.to_csv(filepath, index = False)
